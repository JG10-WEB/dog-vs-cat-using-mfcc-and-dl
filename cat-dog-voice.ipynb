wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/test/cats/cat_79.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/test/cats/cat_112.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/test/cats/cat_90.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/test/cats/cat_115.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/test/cats/cat_85.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/test/cats/cat_14.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/test/cats/cat_82.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/test/cats/cat_55.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_102.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_29.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_50.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_83.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_30.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_98.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_33.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_32.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_2.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_17.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_6.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_88.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_101.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_94.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_13.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_60.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_85.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_27.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_42.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_1.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_93.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_52.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_72.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_18.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_56.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_25.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_4.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_92.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_70.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_28.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_21.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_10.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_100.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_63.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_58.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_41.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_53.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_106.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_16.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_84.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_97.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_47.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_71.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_79.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_26.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_81.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_110.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_80.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_36.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_5.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_103.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_14.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_74.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_55.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_109.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_51.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_0.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_38.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_75.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_76.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_77.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_37.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_22.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_67.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_95.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_23.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_68.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_86.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_108.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_61.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_39.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_31.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_40.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_20.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_104.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_87.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_65.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_57.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_111.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_107.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_69.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_105.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_11.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_96.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/dog/dog_barking_35.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_43.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_47.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_83.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_84.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_74.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_124.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_89.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_52.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_21.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_103.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_153.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_165.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_70.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_100.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_13.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_63.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_11.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_109.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_136.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_150.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_139.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_69.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_72.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_156.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_120.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_19.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_128.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_141.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_68.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_93.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_142.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_10.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_91.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_45.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_38.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_119.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_167.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_116.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_96.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_106.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_157.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_6.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_73.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_4.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_160.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_25.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_159.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_162.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_26.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_54.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_51.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_98.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_127.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_87.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_22.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_125.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_149.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_107.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_7.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_41.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_131.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_5.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_123.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_99.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_163.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_23.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_34.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_64.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_151.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_140.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_53.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_134.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_35.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_49.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_37.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_1.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_33.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_94.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_44.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_78.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_77.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_166.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_118.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_48.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_113.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_9.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_31.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_132.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_108.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_15.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_27.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_46.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_161.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_146.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_164.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_121.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_60.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_122.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_101.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_80.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_95.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_40.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_8.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_71.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_81.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_155.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_39.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_147.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_16.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_102.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_92.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_62.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_154.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_117.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_114.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_2.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_12.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_105.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_30.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_18.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_65.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_138.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_32.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_97.wav
# /kaggle/input/audio-cats-and-dogs/cats_dogs/train/cat/cat_50.wav

# %%
import librosa
import librosa.display
import os
import pylab
from pathlib import Path
import numpy as np
# !pip install split-folders
import splitfolders 
from tensorflow.keras.applications import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import  Dense, Flatten, Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint,EarlyStopping ,TensorBoard
from tensorflow.keras import regularizers
import tensorflow as tf
import datetime
from keras.models import load_model
import glob
import random
from PIL import Image
from IPython.display import display
from ipywidgets import widgets, HBox
# Out:
# Collecting split-folders
#   Downloading split_folders-0.4.3-py3-none-any.whl (7.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.4.3

# %%
def audio_to_spectogam(path):
        y, sr = librosa.load(path, mono=True)
        mel=librosa.feature.melspectrogram(y=y, sr=sr)
        pylab.figure(figsize=(3,3))
        pylab.axis('off') 
        pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[]) 
        log_power = librosa.power_to_db(mel, ref=np.max)
        librosa.display.specshow(log_power)
        filename=Path(path).stem
        if filename[0]=='c':
            folder_path = './data/cats'
        else: folder_path = './data/dogs'
        pylab.savefig(os.path.join(folder_path,filename) + ".jpg", bbox_inches=None, pad_inches=0)
        pylab.close()

# %%
if not os.path.exists("./data"):
    os.makedirs("./data")
if not os.path.exists("./data/cats"):
    os.makedirs("./data/cats")
if not os.path.exists("./data/dogs"):
    os.makedirs("./data/dogs")

for i in os.scandir('../input/audio-cats-and-dogs/cats_dogs'):
    if os.path.splitext(i)[1] == '.wav':
        audio_to_spectogam(i)

# %%
dogs_folder = "./data/dogs"
cats_folder = "./data/cats"
n_samples=4
cats_images=random.sample([os.path.join(cats_folder, f) for f in os.listdir(cats_folder)],n_samples)
dogs_images=random.sample([os.path.join(dogs_folder, f) for f in os.listdir(dogs_folder)],n_samples)

cat_images=[]
for i in range(len(cats_images)):
    cat_images.append(widgets.Image(value=open(cats_images[i], 'rb').read()))
hbox1 = HBox(cat_images)

dog_images=[]
for i in range(len(dogs_images)):
    dog_images.append(widgets.Image(value=open(dogs_images[i], 'rb').read()))
hbox2 = HBox(dog_images)

print("Cats")
display(hbox1)
print("Dogs")
display(hbox2)
# Out:
# Cats
# HBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xdb\x00C\x00\x…
# Dogs
# HBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xdb\x00C\x00\x…

# %%
#split the combined folder into test, train, validation folders
splitfolders.ratio("./data", output="./dataset", seed=1337, ratio=(.7, .15, .15), group_prefix=None)
# Out:
# Copying files: 277 files [00:00, 6269.07 files/s]

# %%
# build the train generator to load and augment the images
train_datagen=ImageDataGenerator(rescale=1./255,
                                 horizontal_flip=False,
                                 preprocessing_function=preprocess_input)
train_generator=train_datagen.flow_from_directory("./dataset/train",
                                                  target_size=(150,150),color_mode="rgb",
                                                  batch_size=8,class_mode="categorical")

# build the validation generator 
val_datagen=ImageDataGenerator(rescale=1./255,preprocessing_function=preprocess_input)
val_generator=val_datagen.flow_from_directory("./dataset/val",
                                                  target_size=(150,150),color_mode="rgb",
                                                  batch_size=8,class_mode="categorical")
# Out:
# Found 193 images belonging to 2 classes.
# Found 40 images belonging to 2 classes.

# %%
# using transfer learning on the VGG16 network with imagenet weights
base_model=VGG16(weights="imagenet",include_top=False,input_shape=(150,150,3))
#calculate the step per epoch size
step_size_train=train_generator.n//train_generator.batch_size
print("step size train:",step_size_train)
step_size_val=val_generator.n//val_generator.batch_size
print("step size test:",step_size_val)

VGG16_self=Sequential()
VGG16_self.add(base_model)
VGG16_self.add(Flatten())
VGG16_self.add(Dense(2,activation="softmax"))
# only the added layers going to train 
base_model.trainable=False
VGG16_self.compile(loss="categorical_crossentropy",optimizer="adam",metrics=["accuracy"])
# callbacks for saving the best model, early stopping and tensorboard
callbacks = [
ModelCheckpoint(str(datetime.datetime.now())+"_vgg16.h5",
                monitor='val_accuracy', verbose=1, save_best_only=True,
                save_weights_only=False, mode='auto', save_freq='epoch'),
EarlyStopping(monitor='val_accuracy', min_delta=0, patience=5, verbose=1, mode='auto')]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# step size train: 24
# step size test: 5

# %%
# train the model
VGG16_self.fit(train_generator,
                    steps_per_epoch=step_size_train,
                    epochs=10,
                    validation_data=val_generator,
                    validation_steps=step_size_val,
                     callbacks=callbacks)
# Out:
# Epoch 1/10
# 24/24 [==============================] - 28s 1s/step - loss: 0.6225 - accuracy: 0.6672 - val_loss: 0.3813 - val_accuracy: 0.8000
#
# Epoch 00001: val_accuracy improved from -inf to 0.80000, saving model to 2021-02-25 11:12:46.399438_vgg16.h5
# Epoch 2/10
# 24/24 [==============================] - 27s 1s/step - loss: 0.3054 - accuracy: 0.8370 - val_loss: 0.3482 - val_accuracy: 0.8250
#
# Epoch 00002: val_accuracy improved from 0.80000 to 0.82500, saving model to 2021-02-25 11:12:46.399438_vgg16.h5
# Epoch 3/10
# 24/24 [==============================] - 26s 1s/step - loss: 0.1931 - accuracy: 0.9485 - val_loss: 0.3268 - val_accuracy: 0.8500
#
# Epoch 00003: val_accuracy improved from 0.82500 to 0.85000, saving model to 2021-02-25 11:12:46.399438_vgg16.h5
# Epoch 4/10
# 24/24 [==============================] - 26s 1s/step - loss: 0.1671 - accuracy: 0.9513 - val_loss: 0.2877 - val_accuracy: 0.8500
#
# Epoch 00004: val_accuracy did not improve from 0.85000
# Epoch 5/10
# 24/24 [==============================] - 26s 1s/step - loss: 0.1083 - accuracy: 0.9840 - val_loss: 0.3229 - val_accuracy: 0.8500
#
# Epoch 00005: val_accuracy did not improve from 0.85000
# Epoch 6/10
# 24/24 [==============================] - 26s 1s/step - loss: 0.1165 - accuracy: 0.9715 - val_loss: 0.2910 - val_accuracy: 0.8500
#
# Epoch 00006: val_accuracy did not improve from 0.85000
# Epoch 7/10
# 24/24 [==============================] - 26s 1s/step - loss: 0.0727 - accuracy: 0.9979 - val_loss: 0.2844 - val_accuracy: 0.8500
#
# Epoch 00007: val_accuracy did not improve from 0.85000
# Epoch 8/10
# 24/24 [==============================] - 26s 1s/step - loss: 0.0867 - accuracy: 0.9946 - val_loss: 0.2943 - val_accuracy: 0.8500
#
# Epoch 00008: val_accuracy did not improve from 0.85000
# Epoch 00008: early stopping

# %%
# build the the test generator
test_datagen=ImageDataGenerator(rescale=1./255,preprocessing_function=preprocess_input)
test_generator=test_datagen.flow_from_directory("./dataset/test",
                                                  target_size=(150,150),color_mode="rgb",
                                                  batch_size=1,class_mode="categorical")
best_acc=0
best_loss=100
# load the best model
models = (glob.glob('./*.h5'))
for a_model in models:
          model = load_model(a_model)
          # evaluate the model on a unseen data
          scoreSeg = model.evaluate(test_generator)
          if scoreSeg[1] > best_acc and scoreSeg[0]<best_loss:
                best_acc = scoreSeg[1]
                best_loss = scoreSeg[0]
                best_model = a_model
                
print('best loss:',best_loss)
print('best accuracy:',best_acc)
# Out:
# Found 44 images belonging to 2 classes.
# 44/44 [==============================] - 7s 126ms/step - loss: 0.1819 - accuracy: 0.9318
# best loss: 0.181899294257164
# best accuracy: 0.9318181872367859

# %%
print(best_model)
# Out:
# ./2021-02-25 11:12:46.399438_vgg16.h5

# %%
import pandas as pd #Importing the libraries
import numpy as np
import glob

# %%
#practical approach to  deep learning projects using cnn
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Test_root = glob.glob('/content/drive/MyDrive/dog cat librosa/test')[0]    #In Python, the glob module is used to retrieve files/pathnames matching a specified pattern.
Train_root = glob.glob('/content/drive/MyDrive/dog cat librosa/train ')[0]
X_path = glob.glob(Test_root + "/dogs/*")
X_path = X_path + glob.glob(Test_root + "/cats/*")
X_path = X_path + glob.glob(Train_root + "/dog/*")
X_path = X_path + glob.glob(Train_root + "/cat/*")

# %%
import ntpath        #The ntpath module provides os. path functionality on Windows platforms. You can also use it to handle Windows paths on other platforms. 
                    #This module treats both forward slashes ( / ) and backward slashes ( \ ) as directory separators.
y = np.empty((0, 1, ))
for f in X_path:
    if 'cat' in ntpath.basename(f):
        resp = np.array([0])
        resp = resp.reshape(1, 1, )
        y = np.vstack((y, resp))
    elif 'dog' in ntpath.basename(f):
        resp = np.array([1])
        resp = resp.reshape(1, 1, )
        y = np.vstack((y, resp))
print (f)
# Out:
# /content/drive/MyDrive/dog cat librosa/train /cat/cat_161.wav

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_path, y, test_size=0.25, random_state=42)

# %%
import librosa
def librosa_read_wav_files(wav_files):
    if not isinstance(wav_files, list):
        wav_files = [wav_files]
    return [librosa.load(f)[0] for f in wav_files]

# %%
wav_rate = librosa.load(X_train[0])[1]
X_train = librosa_read_wav_files(X_train)
X_test  = librosa_read_wav_files(X_test)

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(2, 2, figsize=(16,7))
axs[0][0].plot(X_train[0])
axs[0][1].plot(X_train[1])
axs[1][0].plot(X_train[2])
axs[1][1].plot(X_train[3])
plt.show()

# %%
def extract_features(audio_samples, sample_rate):
    extracted_features = np.empty((0, 41, ))
    if not isinstance(audio_samples, list):
        audio_samples = [audio_samples]
        
    for sample in audio_samples:
        zero_cross_feat = librosa.feature.zero_crossing_rate(sample).mean()
        mfccs = librosa.feature.mfcc(y=sample, sr=sample_rate, n_mfcc=40)
        mfccsscaled = np.mean(mfccs.T,axis=0)
        mfccsscaled = np.append(mfccsscaled, zero_cross_feat)
        mfccsscaled = mfccsscaled.reshape(1, 41, )
        extracted_features = np.vstack((extracted_features, mfccsscaled))
    return extracted_features

# %%
X_train_features = extract_features(X_train, wav_rate)
X_test_features  = extract_features(X_test, wav_rate)

# %%
from keras import layers
from keras import models
from keras import optimizers
from keras import losses
from keras.callbacks import ModelCheckpoint,EarlyStopping
from keras.utils import to_categorical

# %%
train_labels = to_categorical(y_train)
test_labels = to_categorical(y_test)

# %%
model = models.Sequential()
model.add(layers.Dense(100, activation = 'relu', input_shape = (41, )))
model.add(layers.Dense(50, activation = 'relu'))
model.add(layers.Dense(2, activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               4200
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 102
# =================================================================
# Total params: 9,352
# Trainable params: 9,352
# Non-trainable params: 0
# _________________________________________________________________

# %%
best_model_weights = './base.model'
checkpoint = ModelCheckpoint(
    best_model_weights,
    monitor='val_acc',
    verbose=1,
    save_best_only=True,
    mode='min',
    save_weights_only=False,
    period=1
)
callbacks = [checkpoint]
model.compile(optimizer='adam',
              loss=losses.categorical_crossentropy,
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(
    X_train_features,
    train_labels,
    validation_data=(X_test_features,test_labels),
    epochs = 200, 
    verbose = 1,
    callbacks=callbacks,
)
# Out:
# Epoch 1/200
# 6/6 [==============================] - 1s 113ms/step - loss: 30.5936 - accuracy: 0.3474 - val_loss: 5.6749 - val_accuracy: 0.7143
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 2/200
# 6/6 [==============================] - 0s 14ms/step - loss: 8.2040 - accuracy: 0.6624 - val_loss: 5.9639 - val_accuracy: 0.7143
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 3/200
# 6/6 [==============================] - 0s 13ms/step - loss: 4.9307 - accuracy: 0.6475 - val_loss: 3.2750 - val_accuracy: 0.4444
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 4/200
# 6/6 [==============================] - 0s 15ms/step - loss: 2.7602 - accuracy: 0.5039 - val_loss: 1.1027 - val_accuracy: 0.8413
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 5/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1.1101 - accuracy: 0.8887 - val_loss: 1.6079 - val_accuracy: 0.8730
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 6/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.7448 - accuracy: 0.8921 - val_loss: 1.0483 - val_accuracy: 0.7937
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 7/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.8385 - accuracy: 0.8445 - val_loss: 1.3442 - val_accuracy: 0.7143
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 8/200
# 6/6 [==============================] - 0s 13ms/step - loss: 1.0453 - accuracy: 0.8666 - val_loss: 0.9193 - val_accuracy: 0.8730
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 9/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4734 - accuracy: 0.8956 - val_loss: 0.7998 - val_accuracy: 0.8889
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 10/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.
- val_accuracy: 0.8413
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 76/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0140 - accuracy: 0.9985 - val_loss: 0.8730 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 77/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0163 - accuracy: 0.9927 - val_loss: 0.8847 - val_accuracy: 0.8413
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 78/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.8827 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 79/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0196 - accuracy: 0.9883 - val_loss: 0.8927 - val_accuracy: 0.8413
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 80/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.8914 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 81/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.8985 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 82/200
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.9057 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 83/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0128 - accuracy: 0.9965 - val_loss: 0.9086 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 84/200
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.9241 - val_accuracy: 0.8413
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 85/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.9125 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 86/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.9206 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 87/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.9156 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 88/200
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0138 - accuracy: 0.9985 - val_loss: 0.9180 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 89/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0160 - accuracy: 0.9929 - val_loss: 0.9203 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 90/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0151 - accuracy: 0.9985 - val_loss: 0.9218 - val_accuracy: 0.8413
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 91/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.9527 - val_accuracy: 0.8413
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 92/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.9301 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 93/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0133 - accuracy: 0.9950 - val_loss: 0.9388 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 94/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.9407 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 95/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0073 - accuracy: 0.9985 - val_loss: 0.9417 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 96/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.9668 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 97/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0138 - accuracy: 0.9976 - val_loss: 0.9621 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 98/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.9836 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 99/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.9717 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 100/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.9752 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 101/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.9739 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 102/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.9741 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 103/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.9752 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 104/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0087 - accuracy: 0.9985 - val_loss: 0.9862 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 105/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.9996 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 106/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.9904 - val_accuracy: 0.8413
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 107/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0158 - accuracy: 0.9950 - val_loss: 1.0201 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 108/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.9960 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 109/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.9986 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 110/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 1.0129 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 111/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 1.0018 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 112/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.0092 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 113/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 1.0187 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 114/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0073 - accuracy: 0.9985 - val_loss: 1.0070 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 115/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0138 - accuracy: 0.9976 - val_loss: 1.0135 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 116/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.9845 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 117/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 1.0009 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 118/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 1.0108 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 119/200
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.0224 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 120/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 1.0323 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 121/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 1.0352 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 122/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 1.0351 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 123/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 1.0414 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 124/200
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.0478 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 125/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 1.0450 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 126/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.0487 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 127/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 1.0531 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 128/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 1.0524 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 129/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 1.0578 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 130/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 1.0531 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 131/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 1.0650 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 132/200
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 1.0759 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 133/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 1.0591 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 134/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.0627 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 135/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.0694 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 136/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.0698 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 137/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.0821 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 138/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.0841 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 139/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.0852 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 140/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.0853 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 141/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.0909 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 142/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.0947 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 143/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.0943 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 144/200
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.0945 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 145/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.0973 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 146/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 1.1014 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 147/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.1030 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 148/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.1058 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 149/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.1051 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 150/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.1087 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 151/200
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.1080 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 152/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.1126 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 153/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.1142 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 154/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.1087 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 155/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 1.1116 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 156/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.1115 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 157/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 1.1128 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 158/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.1211 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 159/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.1245 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 160/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 1.1262 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 161/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 1.1241 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 162/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.1255 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 163/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.1408 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 164/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.1367 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 165/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 1.1424 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 166/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.1542 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 167/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.1451 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 168/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.1451 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 169/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.1493 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 170/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.1601 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 171/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.1523 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 172/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.1536 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 173/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 1.1640 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 174/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.1617 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 175/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.1610 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 176/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.1672 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 177/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 1.1637 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 178/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.1615 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 179/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.1700 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 180/200
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.1767 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 181/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.1752 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 182/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.1792 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 183/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 1.1758 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 184/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 1.1767 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 185/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.1795 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 186/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.1813 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 187/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.1838 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 188/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.1852 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 189/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.1934 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 190/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.1930 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 191/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.1973 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 192/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.1992 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 193/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.1961 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 194/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.1990 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 195/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.2036 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 196/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.2060 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 197/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.2045 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 198/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.2075 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 199/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.2085 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 200/200
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.2084 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.

# %%
print(history.history.keys())
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = range(1, len(acc)+1)
plt.plot(epochs, acc, 'b', label = "training accuracy")
plt.plot(epochs, val_acc, 'r', label = "validation accuracy")
plt.title('Training and validation accuracy')
plt.legend()
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
model.save_weights('model_wieghts.h5')
model.save('model_keras.h5')

# %%
nr_to_predict = 5
pred = model.predict(X_test_features[nr_to_predict].reshape(1, 41,))
print("Cat: {} Dog: {}".format(pred[0][0], pred[0][1]))
if (y_test[nr_to_predict] == 0):
    print ("This is a cat meowing")
else:
    print ("This is a dog barking")
    
plt.plot(X_test_features[nr_to_predict])
#ipd.Audio(X_test[nr_to_predict],  rate=wav_rate)
# Out:
# Cat: 0.9994761347770691 Dog: 0.0005239167367108166
# This is a cat meowing

# %%
nr_to_predict = 2
pred = model.predict(X_test_features[nr_to_predict].reshape(1, 41,))
print("Cat: {} Dog: {}".format(pred[0][0], pred[0][1]))
if (y_test[nr_to_predict] == 0):
    print ("This is a cat meowing")
else:
    print ("This is a dog barking")
    
plt.plot(X_test_features[nr_to_predict])
#ipd.Audio(X_test[nr_to_predict],  rate=wav_rate)
# Out:
# Cat: 5.630294708680594e-06 Dog: 0.9999943971633911
# This is a dog barking
